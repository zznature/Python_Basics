# %% [markdown]
# # Test PySimpleGUI

# %% [markdown]
# # Qt
# I would adopt Qt as interface framework.

# %%
import PySimpleGUI as sg

# %%
import PySimpleGUI as sg

layout = [
    [sg.Text('一句话概括Python')],
    [sg.Input(key='-INPUT-')],
    [sg.Button('确认'), sg.Button('取消')]
]
window = sg.Window('PySimpleGUI Demo', layout)
while True:
    event, values = window.read()
    print(event)
    print(values)
    if event in (None, '取消'):
        break
window.close()
# Out:
# 2022-01-13 20:42:32.009 python[80796:5130752] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
# 确认
# {'-INPUT-': 'ok'}
# 确认
# {'-INPUT-': 'ok, this=that'}
# 取消
# {'-INPUT-': 'ok, this=that'}

# %% [markdown]
# Preview themes

# %%
sg.preview_all_look_and_feel_themes()
